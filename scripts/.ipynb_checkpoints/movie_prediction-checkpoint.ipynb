# %% [markdown]
# # 2019 DACON Tutorial Competition : 관객수 예측

# %% [markdown]
# ### 목차
# **1. 데이터 탐색**<br>
# **2. Feature Engineering**<br>
# **3. Modeling**<br>

# %% [markdown]
# ## 1. 데이터 탐색

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from scipy import stats
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# 한글 폰트 적용
mpl.rcParams['axes.unicode_minus'] = False
mpl.rcParams['font.family'] = 'NanumBarunGothic'

# %%
# 데이터 읽어오기
train = pd.read_csv('../movies_train.csv')
test = pd.read_csv('../movies_test.csv')

# %%
train.head(50)
# Out:
#                          title      distributor   genre release_time  time  \
# 0                       개들의 전쟁         롯데엔터테인먼트      액션   2012-11-22    96
# 1                         내부자들           (주)쇼박스     느와르   2015-11-19   130
# 2                    은밀하게 위대하게           (주)쇼박스      액션   2013-06-05   123
# 3                     나는 공무원이다           (주)NEW     코미디   2012-07-12   101
# 4                         불량남녀     쇼박스(주)미디어플렉스     코미디   2010-11-04   108
# 5               강철대오 : 구국의 철가방         롯데엔터테인먼트     코미디   2012-10-25   113
# 6                         길위에서             백두대간   다큐멘터리   2013-05-23   104
# 7                          회사원           (주)쇼박스      액션   2012-10-11    96
# 8              1789, 바스티유의 연인들  유니버설픽쳐스인터내셔널코리아     뮤지컬   2014-09-18   129
# 9                        청춘그루브           (주)두타연     드라마   2012-03-15    94
# 10                      AV 아이돌        (주) 케이알씨지  멜로/로맨스   2015-07-27    89
# 11                       무서운 집         (주)콘텐츠 윙      공포   2015-07-30    98
# 12                          해로          (주)키노아이     드라마   2012-03-22   113
# 13                           짓        (주)팝 파트너스    서스펜스   2013-09-25   107
# 14                     철가방 우수氏      CJ E&M 영화부문     드라마   2012-11-22   100
# 15                      자유의 언덕      (주) 영화제작전원사     드라마   2014-09-04    67
# 16                          써니  CJ E&M Pictures     코미디   2011-05-04   124
# 17                    별이 빛나는 밤        CGV 무비꼴라쥬     드라마   2012-04-05    98
# 18                          카트           리틀빅픽처스     드라마   2014-11-13   104
# 19                         하하하              스폰지     드라마   2010-05-05   115
# 20                   두근두근 내 인생        CJ 엔터테인먼트     드라마   2014-09-03   117
# 21                 성실한 나라의 앨리스         CGV아트하우스     드라마   2015-08-13    90
# 22                          원령           조이앤시네마      공포   2015-08-13    91
# 23                      관능의 법칙         롯데엔터테인먼트     드라마   2014-02-13   108
# 24                      안녕, 투이            인디플러그     드라마   2014-11-27   106
# 25                          영도            콘텐츠판다     드라마   2015-09-10   116
# 26                      이웃집 좀비            인디스토리      공포   2010-02-18    89
# 27           러브앤서울 복숭아마을 도색소동기        (주) 케이알씨지  멜로/로맨스   2015-07-27    89
# 28                         무법자           (주)NEW     느와르   2010-03-18    93
# 29            일탈여행 : 프라이빗 아일랜드       (주)팝엔터테인먼트     드라마   2013-08-29    90
# 30                      로맨틱 헤븐           시네마서비스     드라마   2011-03-24   117
# 31                        겨울나비             웃기씨네     드라마   2011-07-07    90
# 32                      다이노 타임        CJ 엔터테인먼트   애니메이션   2015-04-30    85
# 33                     물 없는 바다            인디스토리  멜로/로맨스   2011-12-08    88
# 34                      오싹한 연애        CJ 엔터테인먼트  멜로/로맨스   2011-12-01   114
# 35                    마이 페어 웨딩           영화사 진진   다큐멘터리   2015-06-04    94
# 36                      원나잇 온리      (주)레인보우 팩토리     드라마   2014-07-03    67
# 37                         일대일           김기덕 필름     드라마   2014-05-22   122
# 38                    하늘의 황금마차           영화사 진진     드라마   2014-09-04    84
# 39                        러브픽션              NEW  멜로/로맨스   2012-02-29   121
# 40                    불타는 내 마음           CJ CGV  멜로/로맨스   2010-03-25    95
# 41                       끝과 시작         롯데엔터테인먼트  멜로/로맨스   2013-04-04    87
# 42                      7월 32일  동국대학교 충무로영상제작센터     드라마   2010-04-22    96
# 43           청춘학당 : 풍기문란 보쌈 야사     BoXoo 엔터테인먼트  멜로/로맨스   2014-03-27    90
# 44                        부당거래        CJ 엔터테인먼트     느와르   2010-10-28   119
# 45                    콘돌은 날아간다        (주)마운틴픽쳐스     드라마   2013-05-30   102
# 46                       페어 러브        CJ 엔터테인먼트     드라마   2010-01-14   117
# 47                     극적인 하룻밤        CGV 아트하우스  멜로/로맨스   2015-12-03   107
# 48                         빅매치           (주)NEW      액션   2014-11-26   112
# 49  극장판 뛰뛰빵빵 구조대 미션: 둥둥이를 구하라!      메가박스(주)플러스엠   애니메이션   2014-08-07    80
#
#    screening_rat director  dir_prev_bfnum  dir_prev_num  num_staff  num_actor  \
# 0       청소년 관람불가      조병옥             NaN             0         91          2
# 1       청소년 관람불가      우민호    1.161602e+06             2        387          3
# 2        15세 관람가      장철수    2.207752e+05             4        343          4
# 3         전체 관람가      구자홍    2.389400e+04             2         20          6
# 4        15세 관람가      신근호    1.000000e+00             1        251          2
# 5        15세 관람가      육상효    8.379690e+05             2        262          4
# 6         전체 관람가      이창재             NaN             0         32          5
# 7       청소년 관람불가      임상윤    7.395220e+05             3        342          2
# 8         전체 관람가      정성복             NaN             0          3          5
# 9        15세 관람가      변성현             NaN             0        138          3
# 10      청소년 관람불가   조조 히데오             NaN             0          0          4
# 11       12세 관람가      양병간             NaN             0          0          1
# 12       12세 관람가      최종태    4.312310e+05             1         14          2
# 13      청소년 관람불가      한종훈    5.342325e+05             2         15          4
# 14       12세 관람가      윤학렬             NaN             0        152          1
# 15      청소년 관람불가      홍상수             NaN             0         52          3
# 16       15세 관람가      강형철    8.223342e+06             1        572         11
# 17        전체 관람가      린슈유    7.730000e+02             1          8          4
# 18       12세 관람가      부지영             NaN             0        359          4
# 19      청소년 관람불가      홍상수             NaN             0         74          9
# 20       12세 관람가      이재용    4.950685e+05             2        466          3
# 21      청소년 관람불가      안국진             NaN             0        228          1
# 22       15세 관람가      동지견             NaN             0          0          1
# 23      청소년 관람불가      권칠인    7.574000e+04             1        288          3
# 24      청소년 관람불가      김재한             NaN             0        153          3
# 25      청소년 관람불가      손승웅             NaN             0        183          3
# 26       15세 관람가       류훈             NaN             0         40         10
# 27      청소년 관람불가   조조 히데오             NaN             0          0          4
# 28      청소년 관람불가      김철한             NaN             0        250          3
# 29      청소년 관람불가      한상희             NaN             0         29          3
# 30       12세 관람가       장진             NaN             0        369          7
# 31       15세 관람가      김규민             NaN             0         71          2
# 32        전체 관람가      최윤석             NaN             0         10          8
# 33       15세 관람가      김관철             NaN             0          9          2
# 34       12세 관람가      황인호    6.832133e+05             3        324          2
# 35       12세 관람가      장희선             NaN             0          2          2
# 36      청소년 관람불가     김조광수             NaN             0          1          5
# 37      청소년 관람불가      김기덕             NaN             0        135          2
# 38       12세 관람가       오멸             NaN             0         96          5
# 39       15세 관람가      전계수    8.052500e+03             2        315          2
# 40       15세 관람가      최원섭             NaN             0         95          2
# 41      청소년 관람불가      민규동    4.598985e+06             1        182          3
# 42      청소년 관람불가      진승현             NaN             0         10          4
# 43      청소년 관람불가      도창훈             NaN             0        100          4
# 44      청소년 관람불가      류승완             NaN             0        471          4
# 45      청소년 관람불가      전수일    9.840000e+02             1         23          3
# 46       12세 관람가      신연식             NaN             0        106          2
# 47      청소년 관람불가      하기호             NaN             0        368          4
# 48       15세 관람가       최호    1.159954e+06             2        600          4
# 49        전체 관람가      방형우             NaN             0         44          3
#
#     box_off_num
# 0         23398
# 1       7072501
# 2       6959083
# 3        217866
# 4        483387
# 5        233211
# 6         53526
# 7       1110523
# 8          4778
# 9           868
# 10          745
# 11         1079
# 12         5851
# 13        23052
# 14        92404
# 15        39317
# 16      7453715
# 17         5693
# 18       814570
# 19        57029
# 20      1624573
# 21        44074
# 22          914
# 23       781516
# 24         1176
# 25         3094
# 26         2807
# 27          745
# 28       160734
# 29         3460
# 30        73729
# 31          521
# 32       285084
# 33          390
# 34      3009406
# 35         4586
# 36         2923
# 37        10142
# 38         2703
# 39      1726227
# 40         9089
# 41        38809
# 42          742
# 43         3772
# 44      2723028
# 45         1209
# 46        27083
# 47       321641
# 48      1177435
# 49        21939

# %% [markdown]
# **데이터 설명**<br>
# 1. title : 영화의 제목
# 2. distributor : 배급사
# 3. genre : 장르
# 4. release_time : 개봉일
# 5. time : 상영시간(분)
# 6. screening_rat : 상영등급
# 7. director : 감독이름
# 8. dir_prev_bfnum : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화에서의 평균 관객수(단 관객수가 알려지지 않은 영화 제외)
# 9. dir_prev_num : 해당 감독이 이 영화를 만들기 전 제작에 참여한 영화의 개수(단 관객수가 알려지지 않은 영화 제외)
# 10. num_staff : 스텝수
# 11. num_actor : 주연배우수
# 12.	box_off_num : 관객수

# %%
# 특징 수
print(train.columns, '/ Num :', len(train.columns))
print(test.columns, '/ Num :', len(test.columns))
# Out:
# Index(['title', 'distributor', 'genre', 'release_time', 'time',
#        'screening_rat', 'director', 'dir_prev_bfnum', 'dir_prev_num',
#        'num_staff', 'num_actor', 'box_off_num'],
#       dtype='object') / Num : 12
# Index(['title', 'distributor', 'genre', 'release_time', 'time',
#        'screening_rat', 'director', 'dir_prev_bfnum', 'dir_prev_num',
#        'num_staff', 'num_actor'],
#       dtype='object') / Num : 11

# %% [markdown]
# ### 1.1 목적변수 탐색
# 목적변수인 box_off_num(관객수) 를 탐색해보자

# %%
fig, ax = plt.subplots(1,1,figsize=(8,5))
sns.distplot(train['box_off_num'], ax=ax)

# %% [markdown]
# 왼쪽으로 많이 치우쳐 오른쪽으로 꼬리가 긴 분포를 가지는 것을 확인이 가능하다. 이 변수를 그대로 학습시키기에는 데이터가 편향되어있어 정규분포에 가깝게 변환이 필요해 보인다.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,6))
stats.probplot(x=train['box_off_num'], plot = axes[0])
stats.probplot(x=np.log1p(train['box_off_num']), plot = axes[1])
plt.show()

# %% [markdown]
# 로그를 취하니 정규 분포에 가까워지는 것을 확인이 가능하다. 다시 히스토그램을 그려 확인해보자.

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.distplot(np.log1p(train['box_off_num']), ax=ax)

# %% [markdown]
# 히스토그램을 보니 쌍봉 분포를 띄고있다. 이는 해당 목적변수 안에 서로 다른 특징을 가지는 두개의 집단으로 나뉜다는 것을 의미하는데, 조금 더 탐색의 여지가 있어보인다.<br>
# 이제 목적변수를 로그함수로 재표현 해주도록 하자!

# %%
# 정규분포에 가깝게 목적변수(관객 수) 변형(재표현)
train['box_off_num'] = np.log1p(train['box_off_num'])

# %%
# Skewness and kurtosis
print('Skewness :', train['box_off_num'].skew())
print('Kurtosis :', train['box_off_num'].kurt())
# Out:
# Skewness : 0.13382333522771098
# Kurtosis : -1.0502133448839133

# %% [markdown]
# ### 1.2 변수 시각화
# * 설명 변수들과 반응 변수(관객 수)간의 상관계수를 확인하기 전에
# * 범주형 변수들을 텍스트에서 숫자로 차례로 변형시켜 주자.
# * 범주형 변수 : distributor(배급사), genre(장르), screening_rat(상영등급), director(감독), dir_prev_num(해당 영화의 감독이 이 영화를 만들기 전 제작에 참여한 영화의 갯수)

# %%
# 레이블링하는데 필요한 인코딩 라이브러리
from sklearn.preprocessing import LabelEncoder
# 유니크 개수 확인하기 위해 시각화 라이브러리
import plotly as py
import plotly.graph_objs as go
py.offline.init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
train_unique = []
columns = ['distributor', 'genre', 'screening_rat', 'director', 'dir_prev_num']
all_data = pd.concat([train.drop(['box_off_num'], axis=1),test], axis=0)   # train, test 데이터들을 합쳐서 unique 계산
print(all_data.shape)
all_data['genre'].unique()

for i in columns:
    train_unique.append(len(all_data[i].unique()))
    
unique_train = pd.DataFrame()
unique_train['Columns'] = columns
unique_train['Unique_value'] = train_unique

data = [
    go.Bar(
        x=unique_train['Columns'],
        y=unique_train['Unique_value'],
        name='Unique value in Features',
        textfont = dict(size=20),
        marker= dict(opacity=0.45)
    )
]

layout = go.Layout(
    title = 'Unique Value by Column',
    xaxis = dict(title='Columns', ticklen=5, zeroline=False, gridwidth=2),
    yaxis = dict(title='Value Count', ticklen=5, gridwidth=2),
    showlegend = True
)

fig = go.Figure(data=data, layout=layout)
py.offline.plot(fig)
# Out:
# (843, 11)
# 'file:///Users/gim-yunsu/PycharmProjects/KagglePractice/Dacon_movie_competition/scripts/temp-plot.html'

# %% [markdown]
# * 장르와 상영등급, 해당 감독이 이 영화 전에 참여한 영화 갯수는 각각 12개와 4개, 7개로 완전한 범주형이다.
# * 그러나 배급사와 감독은 각 100개가 넘는 unique 갯수로 범주형이라고 하기엔 조금 애매하다.
# * 일단 확실한 범주형 변수인 장르와 상영등급은 sklearn의 LabelEncoder로 인코딩 해주도록 하자.

# %%
genre_encoder = LabelEncoder()
screen_rat_encoder = LabelEncoder()
prev_num_encoder = LabelEncoder()

# 각 범주에 맞게 피팅시켜준다.
genre_encoder.fit(all_data['genre'])
screen_rat_encoder.fit(all_data['screening_rat'])
prev_num_encoder.fit(all_data['dir_prev_num'])

# 변형시켜 준다
datas = [train, test]
for data in datas:
    data['genre'] = genre_encoder.transform(data['genre'])
    data['screening_rat'] = screen_rat_encoder.transform(data['screening_rat'])
    data['dir_prev_num'] = prev_num_encoder.transform(data['dir_prev_num'])

# %%
train['genre'].unique()
# Out:
# array([10,  2, 11,  3,  6,  4,  5,  1,  8,  9,  7,  0])

# %%
train['screening_rat'].unique()
# Out:
# array([3, 1, 2, 0])

# %%
train['dir_prev_num'].unique()
# Out:
# array([0, 2, 4, 1, 3, 5])

# %% [markdown]
# 위와 같이 각각 컴퓨터가 알아볼 수 있게 숫자로 변형된 것을 확인할 수 있다.<br>
# 이제 변수들간의 상관계수를 확인해 보도록 하자.

# %% [markdown]
# * 피어슨 상관관계 : 연속형 변수에 사용
# * 스피어만 순위 상관관계 : 범주형 변수도 포함되었을 경우에 사용<br>
# 목적변수인 관객수와 상관관계가 높은 순서대로 스피어만 상관계수를 본 히트맵을 그려보자

# %%
# box_off_num correlation matrix
corrmat = abs(train.corr(method='spearman')) # 전체 변수에 대해 correlation 계산
cols = corrmat.nlargest('box_off_num').index # nlargest : return this many descending sorted values
cm = np.corrcoef(train[cols].values.T)

fig, ax = plt.subplots(1,1,figsize=(15,8))
sns.heatmap(data=cm, cbar=True, )

# %% [markdown]
# #### 1.2.1 장르(genre)

# %%
data = train.copy()
data['genre'] = genre_encoder.inverse_transform(data['genre'])
fig, ax = plt.subplots(1,1,figsize=(12,8))
sns.boxplot(x='genre', y='box_off_num', data=data, ax=ax)

# %% [markdown]
# * 액션과 느와르, 코미디는 관객수가 높은쪽으로 분포한다. 대체적으로 잘 팔리는 장르로 볼 수 있겠고, 이상치를 제외하고 재미가없어도 비교적 높은 관객수는 유지되는 장르라고 볼 수 있겠다.
# * 뮤지컬과 서스펜스와 같은 장르는 관객수의 분포가 굉장히 좁은 걸로 보아 매니아들만 관람하는 듯한 경향이 보인다.
# * 드라마와 멜로/로맨스와 같은 장르는 대체적으로는 중간정도의 관객수를 내지만 성공과 실패시 관객수의 폭이 극단적인 경향이 있다.
# * 액션, 느와르, 다큐멘터리, 애니메이션 장르에 이상치가 있는데, 이는 직접 관측이 필요해 보인다.

# %% [markdown]
# #### 1.2.2 상영등급(screening rat)

# %%
data = train.copy()
data['screening_rat'] = screen_rat_encoder.inverse_transform(data['screening_rat'])
fig, ax = plt.subplots(1,1,figsize=(12,8))
sns.boxplot(x='screening_rat', y='box_off_num', data=data, ax=ax)

# %% [markdown]
# * 전체적으로 큰 차이는 없지만 12세 관람가와 15세 관람가 영화가 비교적 높은 관람객을 가지는 경향이 있다.
# * 청소년 관람불가 영화와 전체 관람가 영화가 비교적 관객 수가 낮은 쪽에 몰려있는 경향이 있다.
# * 이상치는 없는듯 하다.

# %% [markdown]
# #### 1.2.3
